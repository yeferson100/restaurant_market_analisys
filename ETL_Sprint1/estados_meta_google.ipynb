# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#Los archivos van desde 1.json hasta 11.json
#Debido al tamaño de los archivos es necesario aplicar una transformacion por cada archivo
import pandas as pd
meta_google1=pd.read_json('/content/drive/MyDrive/Google Maps/metadata-sitios/11.json', lines=True)
#Cambiamos el archivo final para cada archivo en nuestra carpeta /metadata_sitios/

# %%
#Eliminamos  los valores duplicados por ID de usuario
meta_google1.loc[meta_google1.duplicated(subset=['gmap_id'])]
meta_google1 = meta_google1.loc[~meta_google1.duplicated(subset=['gmap_id'])] .reset_index(drop=True).copy()
meta_google1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275001 entries, 0 to 275000
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              274999 non-null  object
#  1   address           270246 non-null  object
#  2   gmap_id           275001 non-null  object
#  3   description       37189 non-null   object
#  4   latitude          275001 non-null  float64
#  5   longitude         275001 non-null  float64
#  6   category          274019 non-null  object
#  7   avg_rating        275001 non-null  float64
#  8   num_of_reviews    275001 non-null  int64
#  9   price             42727 non-null   object
#  10  hours             218334 non-null  object
#  11  MISC              230490 non-null  object
#  12  state             222976 non-null  object
#  13  relative_results  256979 non-null  object
#  14  url               275001 non-null  object
# dtypes: float64(3), int64(1), object(11)
# ...

# %%
#Creamos un campo para asignar un estado
meta_google1['estado']=None

# %%
#Agregamos las abreviaciones que corresponden a cada estado

meta_google1.loc[meta_google1['address'].str[-8:-6]=='MD', 'estado']='MD'
meta_google1.loc[meta_google1['address'].str[-8:-6]=='GA', 'estado']='GA'
meta_google1.loc[meta_google1['address'].str[-8:-6]=='VA', 'estado']='VA'
meta_google1.loc[meta_google1['address'].str[-8:-6]=='NC', 'estado']='NC'
meta_google1.loc[meta_google1['address'].str[-8:-6]=='SC', 'estado']='SC'
meta_google1.loc[meta_google1['address'].str[-8:-6]=='FL', 'estado']='FL'

# %%
#Seleccionamos los comercios que correspondan a los estados seleccionados GA, MD, VA, NC, SC, FL

meta_state=meta_google1[(meta_google1['address'].str[-8:-6]=='GA')|(meta_google1['address'].str[-8:-6]=='MD')|
                (meta_google1['address'].str[-8:-6]=='VA')|(meta_google1['address'].str[-8:-6]=='NC')|
                (meta_google1['address'].str[-8:-6]=='SC')|(meta_google1['address'].str[-8:-6]=='FL')]
meta_state
# Out:
#                                                      name  \
# 0                                         Porter Pharmacy
# 1                                          Mcguinns store
# 2                                   Gentle Hands Grooming
# 4                         Advanced Home Medical Equipment
# 8                                      Black Saddle Ranch
# ...                                                   ...
# 274959  COA New Smyrna Beach Neighborhood Activity Cen...
# 274970                                     Subpreme Grill
# 274977                                 Rhine River Cruise
# 274992                              Enterprise Rent-A-Car
# 274999                                      Ok Feed Store
#
#                                                   address  \
# 0       Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1        Mcguinns store, 4884 NC-9, Mill Spring, NC 28756
# 2       Gentle Hands Grooming, 156 US-176, Saluda, NC ...
# ...

# %%
meta_state.to_csv('meta11.csv', index=False)

# %%
import pandas as pd
df1=pd.read_csv('meta1.csv')
df2=pd.read_csv('meta2.csv')
df3=pd.read_csv('meta3.csv')
df4=pd.read_csv('meta4.csv')
df5=pd.read_csv('meta5.csv')
df6=pd.read_csv('meta6.csv')
df7=pd.read_csv('meta7.csv')
df8=pd.read_csv('meta8.csv')
df9=pd.read_csv('meta9.csv')
df10=pd.read_csv('meta10.csv')
df11=pd.read_csv('meta11.csv')

# %%
data_concat=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11], ignore_index=True)

# %%
data_concat.to_csv('meta_states.csv', index=False)

# %%
data_concat
# Out:
#                                                      name  \
# 0                                         Porter Pharmacy
# 1                                             NTK OUTDOOR
# 2                           Cruises Inc. - Connie Stewart
# 3                              Seminole Family Restaurant
# 4                       First Impressions Barbershop Inc.
# ...                                                   ...
# 559796  COA New Smyrna Beach Neighborhood Activity Cen...
# 559797                                     Subpreme Grill
# 559798                                 Rhine River Cruise
# 559799                              Enterprise Rent-A-Car
# 559800                                      Ok Feed Store
#
#                                                   address  \
# 0       Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1       NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 2       Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
# ...
